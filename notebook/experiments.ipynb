# %%
! uv pip install langchain openai langchain_google_genai tiktoken rapidocr-onnxruntime python-dotenv langchain-community

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
# from dotenc import load_dotenv

# load_dotenv()

# %%
# !uv pip install langchain
# Out:
# Using Python 3.13.5 environment at: C:\Users\kaust\Python\Projects\RAG\.venv
# Audited 1 package in 10ms

# %% [markdown]
# # Data Ingestion

# %%
from langchain.document_loaders import TextLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from langchain.document_loaders import TextLoader
#
# ModuleNotFoundError: No module named 'langchain.document_loaders'
